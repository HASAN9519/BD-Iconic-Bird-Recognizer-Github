# %% [markdown]
# # Notes
#
# Select GPU as runtime
#
# This is a continuation of our project Recognizing Iconic Birds of Bangladesh
#
# The goal of this project is to classify 15 different types of iconic birds of Bangladesh which are found around the country. The birds are in the following: <br/>
# 1. Asian Koel (Kokil)
# 2. Black Drongo (Finge)
# 3. Brahminy Kite (Shankh Chil)
# 4. Common Kingfisher (Machh Ranga)
# 5. Common Myna (Shalik)
# 6. House Crow (Pati Kak)
# 7. House Sparrow (Chorui)
# 8. Indian Pond Heron (Kani Bok)
# 9. Little Cormorant (Pankowri)
# 10. Oriental Magpie-Robin (Doel)
# 11. Red-vented Bulbul (Bulbul)
# 12. Rock Pigeon (Payerra)
# 13. Rose-ringed Parakeet (Tiya Pakhi)
# 14. Spotted Dove (Telaghughu)
# 15. White-breasted Waterhen (Dahuk)

# %% [markdown]
# # Setting Up for Inference

# %%
# !pip install -Uqq fastai

# %%
from fastai import *
from fastai.vision.all import *
from fastai.vision.widgets import *

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd /content/drive/MyDrive/2025_ALL_Master_Course_Works/ALL_DL_CV/CV-Project-2_BD-Iconic-Bird-Recognizer
# Out:
# /content/drive/MyDrive/2025_ALL_Master_Course_Works/ALL_DL_CV/CV-Project-2_BD-Iconic-Bird-Recognizer

# %%
img_path = 'test_images'

# %%
# Loading Model
model = load_learner('models/bird-recognizer-model_resnet34.pkl')
# Out:
# /usr/local/lib/python3.12/dist-packages/fastai/learner.py:455: UserWarning: load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.
# If you only need to load model weights and optimizer state, use the safe `Learner.load` instead.
#   warn("load_learner` uses Python's insecure pickle module, which can execute malicious arbitrary code when loading. Only load files you trust.\nIf you only need to load model weights and optimizer state, use the safe `Learner.load` instead.")

# %% [markdown]
# ## Inference 1
#
# **Target:** Asian Koel (Kokil)

# %%
img = Image.open(f'{img_path}/test-1.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=105x128>

# %%
# predicted right
model.predict(f'{img_path}/test-1.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Asian Koel (Kokil)',
#  tensor(0),
#  tensor([5.4254e-01, 1.8165e-01, 9.4990e-05, 2.9969e-03, 8.2309e-06, 1.2674e-03,
#          6.5792e-05, 1.8780e-04, 2.3726e-02, 5.2710e-04, 6.6565e-02, 1.3380e-03,
#          2.8078e-04, 1.7700e-01, 1.7463e-03]))

# %% [markdown]
# ## Inference 2
#
# **Target:** Black Drongo (Finge)

# %%
img = Image.open(f'{img_path}/test-2.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=110x128>

# %%
# predicted right
model.predict(f'{img_path}/test-2.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Black Drongo (Finge)',
#  tensor(1),
#  tensor([1.3015e-08, 1.0000e+00, 9.3495e-08, 1.3030e-07, 6.1702e-08, 1.4431e-07,
#          6.3963e-07, 5.2213e-10, 1.2463e-06, 1.4934e-06, 2.3025e-10, 1.1032e-07,
#          4.9503e-08, 1.6598e-09, 2.9264e-09]))

# %% [markdown]
# ## Inference 3
# **Target:** Brahminy Kite (Shankh Chil)

# %%
img = Image.open(f'{img_path}/test-3.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
# predicted right
model.predict(f'{img_path}/test-3.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Brahminy Kite (Shankh Chil)',
#  tensor(2),
#  tensor([1.7230e-10, 1.1341e-08, 1.0000e+00, 1.7736e-10, 1.5521e-10, 9.8031e-09,
#          2.6595e-06, 1.1751e-07, 1.5224e-08, 1.9722e-10, 3.6733e-10, 1.4967e-08,
#          6.3177e-09, 1.1889e-07, 4.1326e-09]))

# %% [markdown]
# ## Inference 4
# **Target:** Common Kingfisher (Machh Ranga)

# %%
img = Image.open(f'{img_path}/test-4.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
# predicted right
model.predict(f'{img_path}/test-4.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Common Kingfisher (Machh Ranga)',
#  tensor(3),
#  tensor([2.5091e-07, 5.9655e-10, 1.3404e-10, 1.0000e+00, 1.2728e-09, 3.8538e-10,
#          5.2103e-12, 4.0228e-10, 5.4709e-10, 1.6027e-09, 1.0992e-08, 3.6620e-10,
#          8.1935e-11, 3.1675e-09, 3.8487e-09]))

# %% [markdown]
# ## Inference 5
# **Target:** Common Myna (Shalik)

# %%
img = Image.open(f'{img_path}/test-5.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
# predicted right
model.predict(f'{img_path}/test-5.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Common Myna (Shalik)',
#  tensor(4),
#  tensor([1.2252e-09, 2.5498e-08, 6.2780e-11, 3.1678e-09, 1.0000e+00, 1.7419e-08,
#          1.0029e-08, 1.7657e-08, 2.8888e-09, 7.2763e-10, 3.9951e-09, 1.6220e-07,
#          6.3712e-08, 2.8767e-08, 4.6374e-08]))

# %% [markdown]
# ## Inference 6
# **Target:** House Crow (Pati Kak)

# %%
img = Image.open(f'{img_path}/test-6.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
# predicted right
model.predict(f'{img_path}/test-6.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('House Crow (Pati Kak)',
#  tensor(5),
#  tensor([2.4461e-10, 5.2867e-08, 5.8793e-08, 2.4225e-09, 1.1072e-07, 1.0000e+00,
#          9.1980e-08, 4.3807e-09, 3.0766e-08, 1.3647e-08, 2.5485e-09, 4.5909e-08,
#          3.2288e-08, 9.6384e-08, 7.5242e-08]))

# %% [markdown]
# ## Inference 7
# **Target:** House Sparrow (Chorui)

# %%
img = Image.open(f'{img_path}/test-7.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x95>

# %%
# predicted right
model.predict(f'{img_path}/test-7.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('House Sparrow (Chorui)',
#  tensor(6),
#  tensor([1.5452e-08, 4.4424e-09, 1.8731e-07, 8.2392e-08, 1.6170e-08, 9.9987e-09,
#          9.9999e-01, 2.9455e-07, 6.2989e-09, 1.4590e-07, 7.7134e-08, 2.2227e-07,
#          8.1807e-09, 7.9907e-07, 6.0129e-06]))

# %% [markdown]
# ## Inference 8
# **Target:** Indian Pond Heron (Kani Bok)

# %%
img = Image.open(f'{img_path}/test-8.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
# predicted right
model.predict(f'{img_path}/test-8.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Indian Pond Heron (Kani Bok)',
#  tensor(7),
#  tensor([2.5786e-08, 1.1446e-09, 7.7235e-08, 4.5384e-10, 1.0001e-08, 1.8681e-08,
#          9.9427e-06, 9.9999e-01, 2.7914e-08, 5.4750e-09, 6.9789e-09, 1.0973e-09,
#          1.0514e-08, 4.8342e-10, 3.4976e-08]))

# %% [markdown]
# ## Inference 9
# **Target:** Little Cormorant (Pankowri)

# %%
img = Image.open(f'{img_path}/test-9.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=93x128>

# %%
# predicted right
model.predict(f'{img_path}/test-9.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Little Cormorant (Pankowri)',
#  tensor(8),
#  tensor([6.4398e-07, 7.7067e-07, 1.0991e-06, 3.4049e-07, 1.5972e-06, 2.4095e-06,
#          4.9819e-08, 2.9515e-06, 9.9999e-01, 2.8204e-08, 1.7906e-08, 2.0721e-07,
#          2.0031e-07, 4.4409e-07, 2.1056e-06]))

# %% [markdown]
# ## Inference 10
# **Target:** Oriental Magpie-Robin (Doel)

# %%
img = Image.open(f'{img_path}/test-10.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
# predicted right
model.predict(f'{img_path}/test-10.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Oriental Magpie-Robin (Doel)',
#  tensor(9),
#  tensor([1.2560e-04, 1.4534e-01, 4.0175e-05, 3.0829e-06, 2.0441e-03, 3.1881e-02,
#          1.8173e-03, 2.1137e-04, 5.5494e-06, 8.1003e-01, 3.0836e-05, 6.5871e-03,
#          1.4023e-05, 3.7116e-05, 1.8290e-03]))

# %% [markdown]
# ## Inference 11
# **Target:** Red-vented Bulbul (Bulbul)

# %%
img = Image.open(f'{img_path}/test-11.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x128>

# %%
# predicted right
model.predict(f'{img_path}/test-11.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Red-vented Bulbul (Bulbul)',
#  tensor(10),
#  tensor([8.5070e-06, 2.1253e-05, 1.7504e-05, 1.7897e-05, 3.1468e-05, 6.2518e-06,
#          8.6020e-05, 8.2399e-06, 2.8944e-06, 2.8062e-06, 9.9972e-01, 3.1021e-07,
#          9.7800e-06, 6.2322e-05, 2.3657e-06]))

# %% [markdown]
# ## Inference 12
# **Target:** Rock Pigeon (Payerra)

# %%
img = Image.open(f'{img_path}/test-12.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
# predicted right
model.predict(f'{img_path}/test-12.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Rock Pigeon (Payerra)',
#  tensor(11),
#  tensor([4.8384e-05, 1.6769e-04, 1.6422e-03, 7.7238e-05, 7.3422e-04, 1.5699e-03,
#          1.0867e-03, 4.5247e-02, 1.9634e-03, 6.7662e-03, 8.7143e-05, 9.2390e-01,
#          9.6261e-03, 6.5283e-03, 5.5964e-04]))

# %% [markdown]
# ## Inference 13
# **Target:** Rose-ringed Parakeet (Tiya Pakhi)

# %%
img = Image.open(f'{img_path}/test-13.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x85>

# %%
# predicted right
model.predict(f'{img_path}/test-13.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Rose-ringed Parakeet (Tiya Pakhi)',
#  tensor(12),
#  tensor([8.9616e-08, 1.1860e-08, 4.1158e-08, 2.1890e-07, 1.5803e-07, 4.7619e-09,
#          2.1148e-07, 4.4780e-07, 1.9277e-09, 7.5023e-08, 1.1161e-07, 3.7679e-08,
#          1.0000e+00, 7.3703e-08, 2.2721e-08]))

# %% [markdown]
# ## Inference 14
# **Target:** Spotted Dove (Telaghughu)

# %%
img = Image.open(f'{img_path}/test-14.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x96>

# %%
# predicted right
model.predict(f'{img_path}/test-14.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('Spotted Dove (Telaghughu)',
#  tensor(13),
#  tensor([8.3647e-08, 5.6525e-09, 5.6891e-09, 3.8832e-08, 2.1339e-09, 2.5325e-06,
#          1.7479e-07, 1.5979e-07, 1.6182e-08, 5.6215e-08, 1.4168e-06, 2.2314e-06,
#          8.4353e-09, 9.9999e-01, 3.3561e-07]))

# %% [markdown]
# ## Inference 15
# **Target:** White-breasted Waterhen (Dahuk)

# %%
img = Image.open(f'{img_path}/test-15.jpg')
img.to_thumb(128,128)
# Out:
# <PIL.Image.Image image mode=RGB size=128x92>

# %%
# predicted right
model.predict(f'{img_path}/test-15.jpg')
# Out:
# <style>
#     /* Turns off some styling */
#     progress {
#         /* gets rid of default border in Firefox and Opera. */
#         border: none;
#         /* Needs to be in here for Safari polyfill so background images work as expected. */
#         background-size: auto;
#     }
#     progress:not([value]), progress:not([value])::-webkit-progress-bar {
#         background: repeating-linear-gradient(45deg, #7e7e7e, #7e7e7e 10px, #5c5c5c 10px, #5c5c5c 20px);
#     }
#     .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#         background: #F44336;
#     }
# </style>
# ('White-breasted Waterhen (Dahuk)',
#  tensor(14),
#  tensor([6.9107e-06, 1.6113e-07, 1.3759e-07, 2.5960e-07, 1.6230e-07, 5.0016e-07,
#          6.3319e-08, 2.0891e-07, 9.3390e-07, 8.1332e-07, 3.1930e-07, 2.9617e-05,
#          2.9978e-07, 1.0807e-05, 9.9995e-01]))

# %% [markdown]
# # Observation

# %% [markdown]
# Out of 15 category, model predicted right all of them

# %% [markdown]
# # Deploy in Gradio

# %%
from fastai.vision.all import load_learner
import gradio as gr

# %%
bird_categories = [
    "Asian Koel (Kokil)",
    "Black Drongo (Finge)",
    "Brahminy Kite (Shankh Chil)",
    "Common Kingfisher (Machh Ranga)",
    "Common Myna (Shalik)",
    "House Crow (Pati Kak)",
    "House Sparrow (Chorui)",
    "Indian Pond Heron (Kani Bok)",
    "Little Cormorant (Pankowri)",
    "Oriental Magpie-Robin (Doel)",
    "Red-vented Bulbul (Bulbul)",
    "Rock Pigeon (Payerra)",
    "Rose-ringed Parakeet (Tiya Pakhi)",
    "Spotted Dove (Telaghughu)",
    "White-breasted Waterhen (Dahuk)"
]

len(bird_categories)
# Out:
# 15

# %%
def recognize_image(image):
    # image = PILImage.create(image)
    # image.thumbnail((192,192))
    pred, idx, probs = model.predict(image)
    return dict(zip(bird_categories, map(float, probs)))

# %%
# from PIL import Image

image = gr.Image()
label = gr.Label()
examples = [
    'test_images/test-1.jpg',
    'test_images/test-2.jpg',
    'test_images/test-3.jpg',
    'test_images/test-4.jpg',
    'test_images/test-5.jpg',
    'test_images/test-6.jpg',
    'test_images/test-7.jpg',
    'test_images/test-8.jpg',
    'test_images/test-9.jpg',
    'test_images/test-10.jpg',
    'test_images/test-11.jpg',
    'test_images/test-12.jpg',
    'test_images/test-13.jpg',
    'test_images/test-14.jpg',
    'test_images/test-15.jpg'
    ]

# generalized code
# iface = gr.Interface(fn=recognize_image, inputs=gr.Textbox(), outputs=gr.Textbox())

iface = gr.Interface(fn=recognize_image, inputs=image, outputs=label, examples=examples)

iface.launch(inline=False)
# Out:
# It looks like you are running Gradio on a hosted Jupyter notebook, which requires `share=True`. Automatically setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# * Running on public URL: https://72dbe8bcfecb38f095.gradio.live
#
# This share link expires in 1 week. For free permanent hosting and GPU upgrades, run `gradio deploy` from the terminal in the working directory to deploy to Hugging Face Spaces (https://huggingface.co/spaces)
